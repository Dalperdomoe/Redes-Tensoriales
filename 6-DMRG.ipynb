# %% [markdown]
# # Busqueda de los estados fundamentales
#
# ## Optimizacion Variacional
#
# Dado un Hamiltoniano $H$, el principio variacional dice que para un estado cuantico dado $|\psi>$ siempre se tiene que
# <br>
# <img src="https://drive.google.com/uc?export=view&id=19B6S2WWG_ihtzXRM0bBhwQlAVYYgRgzc" width="200">
# <br>
# $E_0$: Menor eigenvalor de $H$ (Energia del estado base).
# <br>
#
# Si $|\psi>$ pertenece a alguna familia TN (MPS, PEPS, etc) con una dimension interna D fija, siempre podemos aproximarnos a $E_0$ desde arriba al minimizar $<\psi|H|\psi>$
# <br>
# <img src="https://drive.google.com/uc?export=view&id=1gK8MRTaPFgH4pvTl5dOz7YD6bc6WUJz0" width="400">
# <br>
# $\lambda$: multiplicador de lagrange que introduce la ligadura $<\psi|\psi>$ = 1
# <br>
#
# Idealmente: La minimizacion debe hacerse simultaneamente sobre todos los tensores del estado (dificil de implementar e ineficiente)
# <br>
# Estrategia: Minimizar con respecto a un tensor mientras se dejan los otros fijos.
# <br>
# <img src="https://drive.google.com/uc?export=view&id=1WmblsceaMgRtiYgpRWCh_g0a0ompz9Bk" width="600">
# <br>
# <img src="https://drive.google.com/uc?export=view&id=1J_m4pdFntKdITgFFOktX-J1VbdEsfEJy" width="500">
# <br>
# <img src="https://drive.google.com/uc?export=view&id=1JAoja1C9wBUIqBtZwoTqycJejVp_7_M0" width="400">
# <br>
# <img src="https://drive.google.com/uc?export=view&id=1L8GWJxcuCSBEvem88Un1DB4TdIIRnFev" width="200">
# <br>
# <img src="https://drive.google.com/uc?export=view&id=10f3HjqFiD6QdWiCHGcePCKeZXe8m1-OC" width="500">
# <br>
#
# Esta es una ecuacion de eigenvalores para $\vec{A}$ y puede resolverse por medio de algoritmos como Davidson, Lanczos, gradiente descendente, gradiente conjugado.
# <br>
#
# **Si realizamos esta optimizacion para un MPS con condiciones de frontera abiertas entonces obtenemos el algoritmo DMRG**

# %% [markdown]
# ## Algoritmo DMRG para 2 tensores del MPS
#
# 1. MPS en forma canonica mixta con centro de ortogonalidad en $A_l$
# 2. Obtener tensor de enlace $B_{[l,l+1]}$ que es la contraccion de $A_l$ y $A_{l+1}$
# 3. Transformar $H$ en la base de $B_{[l,l+1]}$
# 4. Aplicar $H'$ ($H$ tranformado) a $B_{[l,l+1]}$
# 5. Optimizar $H'B_{[l,l+1]}$
# 6. Restaurar la forma MPS, descomponiendo $B_{[l,l+1]}$ y cambiando el centro de ortogonalidad a $A_{l+1}$
#
#
#
# <img src="https://tensornetwork.org/mps/algorithms/dmrg/summary_opt.png" width="500">
#
# <img src="https://tensornetwork.org/mps/algorithms/dmrg/summary_SVD.png" width="500">

# %%
# -*- coding: utf-8 -*-
"""
The system we consider is the quantum XX-model, which is closely related to the Bose-Hubbard model.


mainDMRG_MPO.py
---------------------------------------------------------------------
Script file for initializing the Hamiltonian of a 1D spin chain as an MPO \
before passing to the DMRG routine.

    by Glen Evenbly (c) for www.tensors.net, (v1.1) - last modified 19/1/2019
"""

#### Preamble
# %matplotlib inline
import numpy as np
from numpy import linalg as LA
import matplotlib.pyplot as plt

from ncon import ncon
from doDMRG_MPO import doDMRG_MPO 

##### Example 1: XX model #############
#######################################

##### Set bond dimensions and simulation options
chi = 16;
Nsites = 50;

OPTS_numsweeps = 4 # number of DMRG sweeps
OPTS_dispon = 2 # level of output display
OPTS_updateon = True # level of output display
OPTS_maxit = 2 # iterations of Lanczos method
OPTS_krydim = 4 # dimension of Krylov subspace

#### Define Hamiltonian MPO (quantum XX model)
chid = 2
sP = np.sqrt(2)*np.array([[0, 0],[1, 0]])
sM = np.sqrt(2)*np.array([[0, 1],[0, 0]])
sX = np.array([[0, 1], [1, 0]]) # pauli matrices
sY = np.array([[0, -1j], [1j, 0]]) #puali matrices
sZ = np.array([[1, 0], [0,-1]]) #pauli matrices
sI = np.array([[1, 0], [0, 1]]) #identity
M = np.zeros([4,4,chid,chid]);
M[0,0,:,:] = sI; M[3,3,:,:] = sI
M[0,1,:,:] = sM; M[1,3,:,:] = sP
M[0,2,:,:] = sP; M[2,3,:,:] = sM
ML = np.array([1,0,0,0]).reshape(4,1,1) #left MPO boundary
MR = np.array([0,0,0,1]).reshape(4,1,1) #right MPO boundary

#### Initialize MPS tensors
A = [0 for x in range(Nsites)] # tensores de la red MPS
A[0] = np.random.rand(1,chid,min(chi,chid))
for k in range(1,Nsites):
    A[k] = np.random.rand(A[k-1].shape[2],chid,min(min(chi,A[k-1].shape[2]*chid),chid**(Nsites-k-1)))

#### Do DMRG sweeps (2-site approach)
En1, Ap, sWeight, B = doDMRG_MPO(A,ML,M,MR,chi, numsweeps = OPTS_numsweeps, dispon = OPTS_dispon, 
                                updateon = OPTS_updateon, maxit = OPTS_maxit, krydim = OPTS_krydim)

#### Increase bond dim and reconverge
chi = 32;
En2, App, sWeight, B = doDMRG_MPO(A,ML,M,MR,chi, numsweeps = OPTS_numsweeps, dispon = OPTS_dispon, 
                                updateon = OPTS_updateon, maxit = OPTS_maxit, krydim = OPTS_krydim)

#### Compare with exact results (computed from free fermions)
H = np.diag(np.ones(Nsites-1),k=1) + np.diag(np.ones(Nsites-1),k=-1)
D = LA.eigvalsh(H)
EnExact = 2*sum(D[D < 0])

##### Plot results
plt.figure(1)
#plt.yscale('log')
plt.plot(range(len(En1)), En1, 'b', label="chi = 16")
plt.plot(range(len(En2)), En2, 'r', label="chi = 32")
plt.legend()
plt.title('DMRG for XX model')
plt.xlabel('Update Step')
plt.ylabel('Ground Energy Error')
plt.show()
# Out:
# Sweep: 1 of 4, Loc: 48,Energy: 39.280655
# Sweep: 1 of 4, Loc: 47,Energy: 35.932964
# Sweep: 1 of 4, Loc: 46,Energy: 31.462907
# Sweep: 1 of 4, Loc: 45,Energy: 28.932496
# Sweep: 1 of 4, Loc: 44,Energy: 27.048341
# Sweep: 1 of 4, Loc: 43,Energy: 24.453159
# Sweep: 1 of 4, Loc: 42,Energy: 23.179570
# Sweep: 1 of 4, Loc: 41,Energy: 20.206146
# Sweep: 1 of 4, Loc: 40,Energy: 17.535237
# Sweep: 1 of 4, Loc: 39,Energy: 15.696598
# Sweep: 1 of 4, Loc: 38,Energy: 14.017905
# Sweep: 1 of 4, Loc: 37,Energy: 11.151792
# Sweep: 1 of 4, Loc: 36,Energy: 8.864924
# Sweep: 1 of 4, Loc: 35,Energy: 6.492238
# Sweep: 1 of 4, Loc: 34,Energy: 4.568736
# Sweep: 1 of 4, Loc: 33,Energy: 2.006752
# Sweep: 1 of 4, Loc: 32,Energy: -0.485588
# Sweep: 1 of 4, Loc: 31,Energy: -2.071705
# Sweep: 1 of 4, Loc: 30,Energy: -5.092054
# Sweep: 1 of 4, Loc: 29,Energy: -7.152349
# Sweep: 1 of 4, Loc: 28,Energy: -9.312050
# Sweep: 1 of 4, Loc: 27,Energy: -11.445169
# Sweep: 1 of 4, Loc: 26,Energy: -13.354822
# ...
